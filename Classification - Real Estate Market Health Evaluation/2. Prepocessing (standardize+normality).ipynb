# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
mydata=pd.read_csv('Final_Data.csv',engine='python')
mydata.head()
# Out:
#    Index RegionType    RegionName          City State  \
# 0      0       City      New York      New York    NY
# 1      1       City   Los Angeles   Los Angeles    CA
# 2      2       City       Chicago       Chicago    IL
# 3      3       City       Houston       Houston    TX
# 4      4       City  Philadelphia  Philadelphia    PA
#
#                                 Metro  \
# 0                        New York, NY
# 1  Los Angeles-Long Beach-Anaheim, CA
# 2                         Chicago, IL
# 3                         Houston, TX
# 4                    Philadelphia, PA
#
#                                        CBSATitle  SizeRank  MarketHealthIndex  \
# 0        "New York-Newark-Jersey City, NY-NJ-PA"       0.0           7.818005
# 1           "Los Angeles-Long Beach-Anaheim, CA"       1.0           8.531387
# 2           "Chicago-Naperville-Elgin, IL-IN-WI"       2.0           0.547932
# 3         "Houston-The Woodlands-Sugar Land, TX"       3.0           7.166910
# ...

# %%
df=pd.DataFrame(mydata)
df.count()
# Out:
# Index                                  9964
# RegionType                             9964
# RegionName                             9964
# City                                   9964
# State                                  9964
# Metro                                  9468
# CBSATitle                              9468
# SizeRank                               9964
# MarketHealthIndex                      9964
# SellForGain                            9964
# ZHVI                                   9964
# MoM                                    9964
# YoY                                    9964
# ForecastYoYPctChange                   9964
# NegativeEquity                         9964
# Delinquency                            9964
# DaysOnMarket                           9964
# Zri                                    9964
# QoQ                                    9964
# BEPropCount                            9964
# SampleRate                             9964
# ...

# %% [markdown]
# # standardize

# %%
from sklearn import preprocessing
# import numpy as np
# import pandas as pd
x = df.values[:,9:]
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
normalization = pd.DataFrame(x_scaled)

y= normalization.values
df.iloc[:,9:]=y
df.head()

# a = np.array([X])
# a_scaled = preprocessing.scale(a)
# a_scaled
# Out:
# C:\Users\a\Anaconda3\lib\site-packages\sklearn\utils\validation.py:444: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
#    Index RegionType    RegionName          City State  \
# 0      0       City      New York      New York    NY
# 1      1       City   Los Angeles   Los Angeles    CA
# 2      2       City       Chicago       Chicago    IL
# 3      3       City       Houston       Houston    TX
# 4      4       City  Philadelphia  Philadelphia    PA
#
#                                 Metro  \
# 0                        New York, NY
# 1  Los Angeles-Long Beach-Anaheim, CA
# 2                         Chicago, IL
# 3                         Houston, TX
# 4                    Philadelphia, PA
#
#                                        CBSATitle  SizeRank  MarketHealthIndex  \
# 0        "New York-Newark-Jersey City, NY-NJ-PA"       0.0           7.818005
# ...

# %% [markdown]
# # PP-Plot

# %%
import matplotlib.pyplot as plt
import pylab
import numpy as np
import scipy.stats as stats
 
variable1 = np.random.normal(df.MarketHealthIndex)  
stats.probplot(variable1, dist="norm", plot=pylab)
plt.xlabel("MarketHealthIndex")
pylab.show()

variable2 = np.random.normal(df.SellForGain)  
stats.probplot(variable2, dist="norm", plot=pylab)
plt.xlabel("SellForGain")
pylab.show()

variable3 = np.random.normal(df.ZHVI)  
stats.probplot(variable3, dist="norm", plot=pylab)
plt.xlabel("ZHVI")
pylab.show()

variable4 = np.random.normal(df.MoM)  
stats.probplot(variable4, dist="norm", plot=pylab)
plt.xlabel("MoM")
pylab.show()

variable5 = np.random.normal(df.YoY)  
stats.probplot(variable5, dist="norm", plot=pylab)
plt.xlabel("YoY")
pylab.show()

variable6 = np.random.normal(df.ForecastYoYPctChange)  
stats.probplot(variable6, dist="norm", plot=pylab)
plt.xlabel("ForecastYoYPctChange")
pylab.show()

variable7 = np.random.normal(df.NegativeEquity)  
stats.probplot(variable7, dist="norm", plot=pylab)
plt.xlabel("NegativeEquity")
pylab.show()

variable8 = np.random.normal(df.Delinquency)  
stats.probplot(variable8, dist="norm", plot=pylab)
plt.xlabel("Delinquency")
pylab.show()

variable9 = np.random.normal(df.DaysOnMarket)  
stats.probplot(variable9, dist="norm", plot=pylab)
plt.xlabel("DaysOnMarket")
pylab.show()

variable10 = np.random.normal(df.Zri)  
stats.probplot(variable10, dist="norm", plot=pylab)
plt.xlabel("Zri")
pylab.show()

variable11 = np.random.normal(df.QoQ)  
stats.probplot(variable10, dist="norm", plot=pylab)
plt.xlabel("QoQ")
pylab.show()

variable12 = np.random.normal(df.BEPropCount)  
stats.probplot(variable10, dist="norm", plot=pylab)
plt.xlabel("BEPropCount")
pylab.show()

variable13 = np.random.normal(df.SampleRate)  
stats.probplot(variable10, dist="norm", plot=pylab)
plt.xlabel("SampleRate")
pylab.show()

variable14 = np.random.normal(df.MedBE)  
stats.probplot(variable10, dist="norm", plot=pylab)
plt.xlabel("MedBE")
pylab.show()

variable15 = np.random.normal(df.MedPR)  
stats.probplot(variable10, dist="norm", plot=pylab)
plt.xlabel("MedPR")
pylab.show()

variable16 = np.random.normal(df.TotalAmountofNegativeEquityMillions)  
stats.probplot(variable10, dist="norm", plot=pylab)
plt.xlabel("TotalAmountofNegativeEquityMillions")
pylab.show()

variable17 = np.random.normal(df.TotalNumberofHomesinNegativeEquity)  
stats.probplot(variable10, dist="norm", plot=pylab)
plt.xlabel("TotalNumberofHomesinNegativeEquity")
pylab.show()

variable18 = np.random.normal(df.NegativeEquityDeliquencyRate)  
stats.probplot(variable10, dist="norm", plot=pylab)
plt.xlabel("MarketHealthIndex")
pylab.show()

# df.SellForGain.hist()
# plt.show()
# Out:
# ((array([-3.80971786, -3.58451635, -3.46087705, ...,  3.46087705,
#           3.58451635,  3.80971786]),
#   array([ -2.19771949,  -2.16180914,  -2.13448695, ...,  12.28212776,
#           12.58996008,  12.86193235])),
#  (3.0221159039368248, 5.0145936216666254, 0.98911355115500399))
# ((array([-3.80971786, -3.58451635, -3.46087705, ...,  3.46087705,
#           3.58451635,  3.80971786]),
#   array([  -3.90808161,   -2.90856455,   -2.57021607, ...,  103.33310179,
#           103.42977477,  103.70396169])),
#  (14.784996214723453, 89.661332365063373, 0.80335046163004864))
# ((array([-3.80971786, -3.58451635, -3.46087705, ...,  3.46087705,
#           3.58451635,  3.80971786]),
#   array([   12256.69117407,    16766.04212669,    17882.7193331 , ...,
#           4740649.16163928,  5026839.93081841,  6935278.74628007])),
#  (199336.72188921159, 261024.29075425703, 0.72347595683193378))
# ((array([-3.80971786, -3.58451635, -3.46087705, ...,  3.46087705,
# ...

# %%
import pandas as pd
mydata=pd.read_csv('after_normalization.csv',engine='python')
mydata.head(20)
# Out:
#     Unnamed: 0  MarketHealthIndex  SellForGain      ZHVI       MoM       YoY  \
# 0            0           7.818005      0.95730  0.092857  0.391177  0.516458
# 1            1           8.531387      0.96370  0.095606  0.429479  0.572632
# 2            2           0.547932      0.81920  0.030885  0.386944  0.462391
# 3            3           7.166910      0.80000  0.023691  0.437753  0.532883
# 4            4           4.831144      0.87600  0.019216  0.432304  0.643848
# 5            5           7.063747      0.88210  0.031141  0.419797  0.582832
# 6            6           4.816545      0.81940  0.035025  0.464327  0.706569
# 7            7           5.806326      0.50000  0.022262  0.432751  0.583020
# 8            8           8.809732      0.96790  0.088618  0.432781  0.579007
# 9            9           9.776156      0.97970  0.153751  0.538239  0.797433
# 10          10           4.101217      0.80760  0.021867  0.446205  0.608595
# ...

# %%
mydata.MarketHealthIndex = mydata.MarketHealthIndex.round(0)
mydata.MarketHealthIndex = mydata.MarketHealthIndex.astype(int)
mydata.head(20)
# Out:
#     Unnamed: 0  MarketHealthIndex  SellForGain      ZHVI       MoM       YoY  \
# 0            0                  8      0.95730  0.092857  0.391177  0.516458
# 1            1                  9      0.96370  0.095606  0.429479  0.572632
# 2            2                  1      0.81920  0.030885  0.386944  0.462391
# 3            3                  7      0.80000  0.023691  0.437753  0.532883
# 4            4                  5      0.87600  0.019216  0.432304  0.643848
# 5            5                  7      0.88210  0.031141  0.419797  0.582832
# 6            6                  5      0.81940  0.035025  0.464327  0.706569
# 7            7                  6      0.50000  0.022262  0.432751  0.583020
# 8            8                  9      0.96790  0.088618  0.432781  0.579007
# 9            9                 10      0.97970  0.153751  0.538239  0.797433
# 10          10                  4      0.80760  0.021867  0.446205  0.608595
# ...

# %%
mydata.to_csv('after_normalization_round.csv', header=True)

# %%
import pandas as pd
mydata=pd.read_csv('after_normalization_round.csv',engine='python')
mydata.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  MarketHealthIndex  SellForGain      ZHVI  \
# 0           0             0                  8       0.9573  0.092857
# 1           1             1                  9       0.9637  0.095606
# 2           2             2                  1       0.8192  0.030885
# 3           3             3                  7       0.8000  0.023691
# 4           4             4                  5       0.8760  0.019216
#
#         MoM       YoY  ForecastYoYPctChange  NegativeEquity  Delinquency  \
# 0  0.391177  0.516458              0.549638        0.116379     0.099894
# 1  0.429479  0.572632              0.594527        0.093381     0.031304
# 2  0.386944  0.462391              0.528597        0.392424     0.040973
# 3  0.437753  0.532883              0.625732        0.162742     0.039081
# 4  0.432304  0.643848              0.638912        0.254035     0.074887
#
#    DaysOnMarket       Zri       QoQ  BEPropCount  SampleRate     MedBE  \
# ...

# %%
Y = mydata.MarketHealthIndex.tolist()
# Out:
# [8,
#  9,
#  1,
#  7,
#  5,
#  7,
#  5,
#  6,
#  9,
#  10,
#  4,
#  10,
#  4,
#  9,
#  10,
#  5,
#  3,
#  4,
#  6,
#  1,
#  8,
#  10,
#  6,
#  9,
#  7,
#  9,
#  6,
#  5,
#  7,
#  7,
#  10,
#  1,
#  3,
#  7,
#  7,
#  7,
#  5,
#  1,
#  8,
#  8,
#  1,
#  9,
#  4,
#  3,
#  6,
#  8,
#  5,
#  2,
#  10,
#  7,
#  6,
#  8,
#  7,
#  8,
#  9,
#  3,
#  3,
#  10,
#  7,
#  9,
#  1,
#  5,
#  8,
#  5,
#  5,
#  8,
#  1,
#  9,
#  9,
#  7,
#  7,
#  5,
#  9,
#  1,
#  8,
#  8,
#  7,
#  1,
#  5,
#  1,
#  8,
#  6,
#  6,
#  7,
#  2,
#  4,
#  9,
#  10,
#  6,
#  5,
#  8,
#  4,
#  4,
#  8,
#  10,
#  4,
#  8,
#  9,
#  10,
#  6,
#  6,
#  3,
#  9,
#  7,
#  4,
#  8,
#  6,
#  1,
#  9,
#  6,
#  9,
#  7,
#  7,
#  9,
#  9,
#  2,
#  4,
#  4,
#  9,
#  8,
#  9,
#  5,
#  8,
#  4,
#  3,
#  6,
#  4,
#  5,
#  4,
#  7,
#  6,
#  9,
#  0,
#  2,
#  4,
#  9,
#  5,
#  7,
#  8,
#  3,
#  7,
#  10,
#  7,
#  2,
#  1,
#  7,
#  3,
#  6,
#  5,
#  9,
#  8,
#  6,
#  3,
#  7,
#  8,
#  3,
#  8,
#  1,
#  6,
#  9,
#  3,
#  2,
#  7,
#  8,
# ...
